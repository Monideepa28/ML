# %% [markdown]
# <a href="https://colab.research.google.com/github/Monideepa28/ML/blob/main/Matplot_fig_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Diagram....***

# %%
import matplotlib.pyplot as plt
plt.plot([1, 3, 2, 9, 5, 3])  # x=[0,1,2,3,4,5,6]
plt.show()

# %%
plt.plot([-3, -2], [1, 6])
# p1=(-3,1)
# p2=(-2,6)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2],[4,4],"b--")
plt.plot([2,3],[4,6],"b--")
plt.plot([3,4],[6,4],"b--")
plt.plot([4,5],[4,4],"b--")
plt.plot([5,4],[4,2],"b--")
plt.plot([4,5],[2,-1],"b--")
plt.plot([5,3],[-1,1],"b--")
plt.plot([3,1],[1,-1],"b--")
plt.plot([1,2],[-1,2],"b--")
plt.plot([2,1],[2,4],"b--")
plt.show()

# %%
import matplotlib.pyplot as plt
#plt.plot([100, 0, ], [100, 100])
plt.plot([0, 0, ], [100, 0],"g-")
#plt.plot([0, 40, ], [0, 0],)
plt.plot([40, 40, ], [0, 40,],"r-")
plt.plot([40, 60, ], [40, 40],"r-")
plt.plot([60, 60, ], [40, 0],"r-")
plt.plot([0, 100, 100, 0, 100, 50, 0], [0, 0, 100, 100, 100, 130, 100],"g-")
#plt.plot([50,130],[100,100])
plt.axis([-12, 120, -11, 160])
plt.show()

# %%
plt.plot([0, 100, 100, 0, 0, 100, 50, 0, 100], [0, 0, 100, 100, 0, 100, 130, 100, 0])
plt.axis([-10, 110, -10, 140]) # collection of x axis and y axis
# x axis= -10,110
# y axis= -10, 140
plt.show()

# %%
plt.plot([0, 100, 100, 0, 0], [0, 0, 100, 100, 0], "r--")
plt.plot([0, 100, 50, 0, 100], [0, 100, 130, 100, 0], "g--")
plt.axis([-10, 110, -10, 140])
plt.show()
